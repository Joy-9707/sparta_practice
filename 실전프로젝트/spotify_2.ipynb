# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
import plotly.express as px
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('/Users/hj/Documents/무제/실전프로젝트/스파르타(튜터) - 스포티파이 데이터.csv')
df
# Out:
#      userid   timestamp    Age  Gender spotify_usage_period  \
# 0        24  2023-07-01  20-35  Female    More than 2 years
# 1        25  2023-07-01  20-35    Male    More than 2 years
# 2        27  2023-07-01  12-20    Male   6 months to 1 year
# 3        50  2023-07-01  20-35    Male    1 year to 2 years
# 4        60  2023-07-01  20-35    Male    More than 2 years
# ..      ...         ...    ...     ...                  ...
# 515     514  2023-07-01  20-35  Female    More than 2 years
# 516     515  2023-07-01  20-35  Female    More than 2 years
# 517     516  2023-07-01  20-35  Female    More than 2 years
# 518     517  2023-07-01  20-35  Female    More than 2 years
# 519     518  2023-07-01  20-35  Female    More than 2 years
#
#                               spotify_listening_device  \
# 0    Smartphone, Computer or laptop, Smart speakers...
# 1                       Smartphone, Computer or laptop
# 2       Smartphone, Smart speakers or voice assistants
# 3    Smartphone, Computer or laptop, Smart speakers...
# 4                 Computer or laptop, Wearable devices
# ..                                                 ...
# 515  Smartphone, Computer or laptop, Smart speakers...
# 516                                         Smartphone
# 517   Smartphone, Computer or laptop, Wearable devices
# 518                     Smartphone, Computer or laptop
# 519                                         Smartphone
#
#        spotify_subscription_plan premium_sub_willingness  \
# 0    Premium (paid subscription)                     Yes
# 1    Premium (paid subscription)                     Yes
# 2    Premium (paid subscription)                     Yes
# 3    Premium (paid subscription)                     Yes
# 4    Premium (paid subscription)                     Yes
# ..                           ...                     ...
# 515          Free (ad-supported)                      No
# 516          Free (ad-supported)                      No
# 517          Free (ad-supported)                     Yes
# 518          Free (ad-supported)                     Yes
# 519          Free (ad-supported)                      No
#
#              preffered_premium_plan preferred_listening_content  ...  \
# 0    Individual Plan- Rs 119/ month                       Music  ...
# 1          Family Plan-Rs 179/month                       Music  ...
# 2          Student Plan-Rs 59/month                     Podcast  ...
# 3    Individual Plan- Rs 119/ month                       Music  ...
# 4          Family Plan-Rs 179/month                       Music  ...
# ..                              ...                         ...  ...
# 515                             NaN                       Music  ...
# 516                             NaN                       Music  ...
# 517        Student Plan-Rs 59/month                       Music  ...
# 518        Student Plan-Rs 59/month                       Music  ...
# 519        Student Plan-Rs 59/month                       Music  ...
#
#                                 music_Influencial_mood  \
# 0    Relaxation and stress relief, Uplifting and mo...
# 1    Relaxation and stress relief, Sadness or melan...
# 2                         Relaxation and stress relief
# 3    Relaxation and stress relief, Uplifting and mo...
# 4    Relaxation and stress relief, Uplifting and mo...
# ..                                                 ...
# 515  Relaxation and stress relief, Uplifting and mo...
# 516                       Relaxation and stress relief
# 517  Uplifting and motivational, Sadness or melancholy
# 518  Relaxation and stress relief, Uplifting and mo...
# 519                       Relaxation and stress relief
#
#                                 music_lis_frequency  \
# 0    While Traveling, Workout session, leisure time
# 1                                       Study Hours
# 2    Office hours, While Traveling, Workout session
# 3    While Traveling, Workout session, leisure time
# 4    While Traveling, Workout session, leisure time
# ..                                              ...
# 515      Study Hours, While Traveling, leisure time
# 516                                 While Traveling
# 517                                 While Traveling
# 518  While Traveling, Workout session, leisure time
# 519                                    leisure time
#
#                       music_expl_method music_recc_rating  \
# 0     recommendations, Playlists, Radio                 1
# 1                recommendations, Radio                 3
# 2                       recommendations                 4
# 3                       recommendations                 4
# 4            recommendations, Playlists                 5
# ..                                  ...               ...
# 515  recommendations, Playlists, Others                 4
# 516          recommendations, Playlists                 4
# 517                     recommendations                 5
# 518                              Others                 2
# 519                     recommendations                 3
#
#         pod_lis_frequency         fav_pod_genre preffered_pod_format  \
# 0                  Rarely                Comedy            Interview
# 1                  Rarely  Lifestyle and Health       Conversational
# 2    Several times a week  Lifestyle and Health        Story telling
# 3                  Rarely                Comedy        Story telling
# 4                   Never                   NaN                  NaN
# ..                    ...                   ...                  ...
# 515                 Never                   NaN                  NaN
# 516                Rarely                   NaN       Conversational
# 517                Rarely  Lifestyle and Health       Conversational
# 518                Rarely                Comedy        Story telling
# 519                 Never                   NaN        Story telling
#
#     pod_host_preference preffered_pod_duration pod_variety_satisfaction
# 0                  Both                Shorter           Very Satisfied
# 1                  Both                   Both                       Ok
# 2                  Both                 Longer                Satisfied
# 3    unknown Podcasters                Shorter           Very Satisfied
# 4                   NaN                    NaN                Satisfied
# ..                  ...                    ...                      ...
# 515                 NaN                    NaN                       Ok
# 516                Both                Shorter                Satisfied
# 517                Both                Shorter                       Ok
# 518                Both                Shorter                       Ok
# 519                Both                Shorter                       Ok
#
# [520 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   userid                       520 non-null    int64
#  1   timestamp                    520 non-null    object
#  2   Age                          520 non-null    object
#  3   Gender                       520 non-null    object
#  4   spotify_usage_period         520 non-null    object
#  5   spotify_listening_device     520 non-null    object
#  6   spotify_subscription_plan    520 non-null    object
#  7   premium_sub_willingness      520 non-null    object
#  8   preffered_premium_plan       312 non-null    object
#  9   preferred_listening_content  520 non-null    object
#  10  fav_music_genre              520 non-null    object
#  11  music_time_slot              520 non-null    object
#  12  music_Influencial_mood       520 non-null    object
#  13  music_lis_frequency          520 non-null    object
#  14  music_expl_method            520 non-null    object
#  15  music_recc_rating            520 non-null    int64
#  16  pod_lis_frequency            520 non-null    object
#  17  fav_pod_genre                372 non-null    object
#  18  preffered_pod_format         380 non-null    object
#  19  pod_host_preference          379 non-null    object
#  20  preffered_pod_duration       391 non-null    object
#  21  pod_variety_satisfaction     520 non-null    object
# dtypes: int64(2), object(20)
# memory usage: 89.5+ KB

# %%
dd = pd.read_csv('/Users/hj/Documents/무제/실전프로젝트/스파르타(튜터) - 매출지표.csv')
dd
# Out:
#       userid    spotify_subscription_plan  revenue   timestamp
# 0          1  Premium (paid subscription)    60000  2023-01-01
# 1          2  Premium (paid subscription)    60000  2023-01-01
# 2          3  Premium (paid subscription)    60000  2023-01-01
# 3          4  Premium (paid subscription)    60000  2023-01-01
# 4          5  Premium (paid subscription)    60000  2023-01-01
# ...      ...                          ...      ...         ...
# 3115     516          Free (ad-supported)        0  2023-06-01
# 3116     517          Free (ad-supported)        0  2023-06-01
# 3117     518          Free (ad-supported)        0  2023-06-01
# 3118     519  Premium (paid subscription)    60000  2023-06-01
# 3119     520  Premium (paid subscription)    60000  2023-06-01
#
# [3120 rows x 4 columns]

# %%
spotify = pd.merge(dd, df, on = 'userid', how='outer')
spotify
# Out:
#       userid  spotify_subscription_plan_x  revenue timestamp_x timestamp_y  \
# 0          1  Premium (paid subscription)    60000  2023-01-01  2023-07-01
# 1          1          Free (ad-supported)        0  2023-02-01  2023-07-01
# 2          1          Free (ad-supported)        0  2023-03-01  2023-07-01
# 3          1          Free (ad-supported)        0  2023-04-01  2023-07-01
# 4          1          Free (ad-supported)        0  2023-05-01  2023-07-01
# ...      ...                          ...      ...         ...         ...
# 3115     520  Premium (paid subscription)    60000  2023-02-01  2023-07-01
# 3116     520  Premium (paid subscription)    60000  2023-03-01  2023-07-01
# 3117     520  Premium (paid subscription)    60000  2023-04-01  2023-07-01
# 3118     520  Premium (paid subscription)    60000  2023-05-01  2023-07-01
# 3119     520  Premium (paid subscription)    60000  2023-06-01  2023-07-01
#
#         Age  Gender spotify_usage_period            spotify_listening_device  \
# 0     20-35  Female    More than 2 years  Smart speakers or voice assistants
# 1     20-35  Female    More than 2 years  Smart speakers or voice assistants
# 2     20-35  Female    More than 2 years  Smart speakers or voice assistants
# 3     20-35  Female    More than 2 years  Smart speakers or voice assistants
# 4     20-35  Female    More than 2 years  Smart speakers or voice assistants
# ...     ...     ...                  ...                                 ...
# 3115  20-35  Female    More than 2 years      Smartphone, Computer or laptop
# 3116  20-35  Female    More than 2 years      Smartphone, Computer or laptop
# 3117  20-35  Female    More than 2 years      Smartphone, Computer or laptop
# 3118  20-35  Female    More than 2 years      Smartphone, Computer or laptop
# 3119  20-35  Female    More than 2 years      Smartphone, Computer or laptop
#
#       spotify_subscription_plan_y  ...  \
# 0             Free (ad-supported)  ...
# 1             Free (ad-supported)  ...
# 2             Free (ad-supported)  ...
# 3             Free (ad-supported)  ...
# 4             Free (ad-supported)  ...
# ...                           ...  ...
# 3115  Premium (paid subscription)  ...
# 3116  Premium (paid subscription)  ...
# 3117  Premium (paid subscription)  ...
# 3118  Premium (paid subscription)  ...
# 3119  Premium (paid subscription)  ...
#
#                                  music_Influencial_mood  \
# 0                                 Sadness or melancholy
# 1                                 Sadness or melancholy
# 2                                 Sadness or melancholy
# 3                                 Sadness or melancholy
# 4                                 Sadness or melancholy
# ...                                                 ...
# 3115  Relaxation and stress relief, Sadness or melan...
# 3116  Relaxation and stress relief, Sadness or melan...
# 3117  Relaxation and stress relief, Sadness or melan...
# 3118  Relaxation and stress relief, Sadness or melan...
# 3119  Relaxation and stress relief, Sadness or melan...
#
#                                     music_lis_frequency music_expl_method  \
# 0                                          leisure time         Playlists
# 1                                          leisure time         Playlists
# 2                                          leisure time         Playlists
# 3                                          leisure time         Playlists
# 4                                          leisure time         Playlists
# ...                                                 ...               ...
# 3115  Office hours,Study Hours, While Traveling, lei...  Playlists, Radio
# 3116  Office hours,Study Hours, While Traveling, lei...  Playlists, Radio
# 3117  Office hours,Study Hours, While Traveling, lei...  Playlists, Radio
# 3118  Office hours,Study Hours, While Traveling, lei...  Playlists, Radio
# 3119  Office hours,Study Hours, While Traveling, lei...  Playlists, Radio
#
#      music_recc_rating pod_lis_frequency fav_pod_genre preffered_pod_format  \
# 0                    3             Daily        Comedy            Interview
# 1                    3             Daily        Comedy            Interview
# 2                    3             Daily        Comedy            Interview
# 3                    3             Daily        Comedy            Interview
# 4                    3             Daily        Comedy            Interview
# ...                ...               ...           ...                  ...
# 3115                 3             Never           NaN                  NaN
# 3116                 3             Never           NaN                  NaN
# 3117                 3             Never           NaN                  NaN
# 3118                 3             Never           NaN                  NaN
# 3119                 3             Never           NaN                  NaN
#
#      pod_host_preference  preffered_pod_duration pod_variety_satisfaction
# 0                   Both                    Both                       Ok
# 1                   Both                    Both                       Ok
# 2                   Both                    Both                       Ok
# 3                   Both                    Both                       Ok
# 4                   Both                    Both                       Ok
# ...                  ...                     ...                      ...
# 3115                 NaN                     NaN                       Ok
# 3116                 NaN                     NaN                       Ok
# 3117                 NaN                     NaN                       Ok
# 3118                 NaN                     NaN                       Ok
# 3119                 NaN                     NaN                       Ok
#
# [3120 rows x 25 columns]

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3120 entries, 0 to 3119
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   userid                       3120 non-null   int64
#  1   spotify_subscription_plan_x  3120 non-null   object
#  2   revenue                      3120 non-null   int64
#  3   timestamp_x                  3120 non-null   object
#  4   timestamp_y                  3120 non-null   object
#  5   Age                          3120 non-null   object
#  6   Gender                       3120 non-null   object
#  7   spotify_usage_period         3120 non-null   object
#  8   spotify_listening_device     3120 non-null   object
#  9   spotify_subscription_plan_y  3120 non-null   object
#  10  premium_sub_willingness      3120 non-null   object
#  11  preffered_premium_plan       1872 non-null   object
#  12  preferred_listening_content  3120 non-null   object
#  13  fav_music_genre              3120 non-null   object
#  14  music_time_slot              3120 non-null   object
#  15  music_Influencial_mood       3120 non-null   object
#  16  music_lis_frequency          3120 non-null   object
#  17  music_expl_method            3120 non-null   object
#  18  music_recc_rating            3120 non-null   int64
#  19  pod_lis_frequency            3120 non-null   object
#  20  fav_pod_genre                2232 non-null   object
#  21  preffered_pod_format         2280 non-null   object
#  22  pod_host_preference          2274 non-null   object
#  23  preffered_pod_duration       2346 non-null   object
#  24  pod_variety_satisfaction     3120 non-null   object
# dtypes: int64(3), object(22)
# memory usage: 609.5+ KB

# %%
spotify[spotify['userid']==3]
# Out:
#     userid  spotify_subscription_plan_x  revenue timestamp_x timestamp_y  \
# 12       3  Premium (paid subscription)    60000  2023-01-01  2023-07-01
# 13       3          Free (ad-supported)        0  2023-02-01  2023-07-01
# 14       3          Free (ad-supported)        0  2023-03-01  2023-07-01
# 15       3  Premium (paid subscription)    60000  2023-04-01  2023-07-01
# 16       3  Premium (paid subscription)    60000  2023-05-01  2023-07-01
# 17       3  Premium (paid subscription)    60000  2023-06-01  2023-07-01
#
#       Age  Gender spotify_usage_period            spotify_listening_device  \
# 12  35-60  Others   6 months to 1 year  Smart speakers or voice assistants
# 13  35-60  Others   6 months to 1 year  Smart speakers or voice assistants
# 14  35-60  Others   6 months to 1 year  Smart speakers or voice assistants
# 15  35-60  Others   6 months to 1 year  Smart speakers or voice assistants
# 16  35-60  Others   6 months to 1 year  Smart speakers or voice assistants
# 17  35-60  Others   6 months to 1 year  Smart speakers or voice assistants
#
#    spotify_subscription_plan_y  ...        music_Influencial_mood  \
# 12         Free (ad-supported)  ...  Relaxation and stress relief
# 13         Free (ad-supported)  ...  Relaxation and stress relief
# 14         Free (ad-supported)  ...  Relaxation and stress relief
# 15         Free (ad-supported)  ...  Relaxation and stress relief
# 16         Free (ad-supported)  ...  Relaxation and stress relief
# 17         Free (ad-supported)  ...  Relaxation and stress relief
#
#              music_lis_frequency music_expl_method music_recc_rating  \
# 12  Study Hours, While Traveling         Playlists                 4
# 13  Study Hours, While Traveling         Playlists                 4
# 14  Study Hours, While Traveling         Playlists                 4
# 15  Study Hours, While Traveling         Playlists                 4
# 16  Study Hours, While Traveling         Playlists                 4
# 17  Study Hours, While Traveling         Playlists                 4
#
#    pod_lis_frequency fav_pod_genre preffered_pod_format pod_host_preference  \
# 12       Once a week        Sports            Interview                 NaN
# 13       Once a week        Sports            Interview                 NaN
# 14       Once a week        Sports            Interview                 NaN
# 15       Once a week        Sports            Interview                 NaN
# 16       Once a week        Sports            Interview                 NaN
# 17       Once a week        Sports            Interview                 NaN
#
#     preffered_pod_duration pod_variety_satisfaction
# 12                    Both                Satisfied
# 13                    Both                Satisfied
# 14                    Both                Satisfied
# 15                    Both                Satisfied
# 16                    Both                Satisfied
# 17                    Both                Satisfied
#
# [6 rows x 25 columns]

# %% [markdown]
# ### 최근 구매일자 구하기 R

# %%
spotify['timestamp_x'] = pd.to_datetime(spotify['timestamp_x'])

positive_revenue_df = spotify[spotify['revenue'] > 0]

most_recent_dates = positive_revenue_df.groupby('userid')['timestamp_x'].max()
most_recent_dates
# Out:
# userid
# 1     2023-01-01
# 2     2023-05-01
# 3     2023-06-01
# 4     2023-06-01
# 5     2023-06-01
#          ...
# 514   2023-06-01
# 515   2023-06-01
# 516   2023-05-01
# 519   2023-06-01
# 520   2023-06-01
# Name: timestamp_x, Length: 354, dtype: datetime64[ns]

# %% [markdown]
# ### 유료 결제 카운트 F

# %%
sales_count_by_user = spotify[spotify['revenue'] >0].groupby('userid')['revenue'].count()
print(sales_count_by_user)
# Out:
# userid
# 1      1
# 2      2
# 3      4
# 4      4
# 5      4
#       ..
# 514    4
# 515    2
# 516    1
# 519    6
# 520    6
# Name: revenue, Length: 354, dtype: int64

# %% [markdown]
# ### 총 지출액 M

# %%
total_payment_by_user = spotify.groupby('userid')['revenue'].sum()
total_payment_by_user
# Out:
# userid
# 1       60000
# 2      120000
# 3      240000
# 4      240000
# 5      240000
#         ...
# 516     60000
# 517         0
# 518         0
# 519    360000
# 520    360000
# Name: revenue, Length: 520, dtype: int64

# %%
# RFM = pd.concat([most_recent_dates, sales_count_by_user, total_payment_by_user], axis = 1)
# RFM.columns = ['Recency', 'Frequency', 'Monetary']

# RFM['Recency'].fillna(pd.NaT, inplace=True)
# RFM['Frequency'].fillna(0, inplace=True)
# RFM['Monetary'].fillna(0, inplace=True)

# %%
# Convert the Series to DataFrames
most_recent_dates_df = most_recent_dates.reset_index(name='Recency')
sales_count_by_user_df = sales_count_by_user.reset_index(name='Frequency')
total_payment_by_user_df = total_payment_by_user.reset_index(name='Monetary')

# Merge the DataFrames on 'userid'
RFM = pd.merge(most_recent_dates_df, sales_count_by_user_df, on='userid', how='outer')
RFM = pd.merge(RFM, total_payment_by_user_df, on='userid', how='outer')

# Fill NaN values with appropriate defaults
RFM['Recency'].fillna(pd.NaT, inplace=True)
RFM['Frequency'].fillna(0, inplace=True)
RFM['Monetary'].fillna(0, inplace=True)
# Out:
# /var/folders/qv/tqmmyp0s5dj996k_tcvqmtqm0000gn/T/ipykernel_5678/980924761.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   RFM['Recency'].fillna(pd.NaT, inplace=True)
# /var/folders/qv/tqmmyp0s5dj996k_tcvqmtqm0000gn/T/ipykernel_5678/980924761.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   RFM['Frequency'].fillna(0, inplace=True)
# /var/folders/qv/tqmmyp0s5dj996k_tcvqmtqm0000gn/T/ipykernel_5678/980924761.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   RFM['Monetary'].fillna(0, inplace=True)

# %%
RFM
# Out:
#      userid    Recency  Frequency  Monetary
# 0         1 2023-01-01        1.0     60000
# 1         2 2023-05-01        2.0    120000
# 2         3 2023-06-01        4.0    240000
# 3         4 2023-06-01        4.0    240000
# 4         5 2023-06-01        4.0    240000
# ..      ...        ...        ...       ...
# 515     516 2023-05-01        1.0     60000
# 516     517        NaT        0.0         0
# 517     518        NaT        0.0         0
# 518     519 2023-06-01        6.0    360000
# 519     520 2023-06-01        6.0    360000
#
# [520 rows x 4 columns]

# %%
RFM.describe()

# 6개월간 총 결제 횟수의 평균값 : 1.5
# 총 결제 횟수의 중위값이 1 임. (전체의 절반이 총 한번밖에 유료결제를 하지 않았음)
# Out:
#            userid                        Recency   Frequency       Monetary
# count  520.000000                            354  520.000000     520.000000
# mean   260.500000  2023-05-02 01:09:09.152542208    1.511538   90692.307692
# min      1.000000            2023-01-01 00:00:00    0.000000       0.000000
# 25%    130.750000            2023-04-01 00:00:00    0.000000       0.000000
# 50%    260.500000            2023-05-01 00:00:00    1.000000   60000.000000
# 75%    390.250000            2023-06-01 00:00:00    2.000000  120000.000000
# max    520.000000            2023-06-01 00:00:00    6.000000  360000.000000
# std    150.255338                            NaN    1.593539   95612.323047

# %%
RFM['Recency'].value_counts()
# Out:
# Recency
# 2023-06-01    164
# 2023-05-01     97
# 2023-04-01     49
# 2023-03-01     34
# 2023-01-01      9
# 2023-02-01      1
# Name: count, dtype: int64

# %%
RFM['Frequency'].value_counts()
# Out:
# Frequency
# 0.0    166
# 1.0    160
# 2.0     84
# 4.0     40
# 3.0     32
# 5.0     26
# 6.0     12
# Name: count, dtype: int64

# %%
RFM['Monetary'].value_counts()
# Out:
# Monetary
# 0         166
# 60000     160
# 120000     84
# 240000     40
# 180000     32
# 300000     26
# 360000     12
# Name: count, dtype: int64

# %%
amount_by_date = spotify.groupby('timestamp_x')[['revenue']].sum().reset_index()

plt.plot(amount_by_date['timestamp_x'], amount_by_date['revenue'])
plt.title('매출 추이')
plt.show()

# %%
RFM['Recency'] = pd.to_datetime(RFM['Recency']) 
today_date = pd.to_datetime(max(spotify['timestamp_y']))

rfm = RFM.groupby('userid').agg({'Recency': lambda x: (today_date - x.max()).days}).reset_index()
RFM = pd.merge(RFM, rfm, on='userid', how='left')
RFM
# Out:
#      userid  Recency_x  Frequency  Monetary  Recency_y
# 0         1 2023-01-01        1.0     60000      181.0
# 1         2 2023-05-01        2.0    120000       61.0
# 2         3 2023-06-01        4.0    240000       30.0
# 3         4 2023-06-01        4.0    240000       30.0
# 4         5 2023-06-01        4.0    240000       30.0
# ..      ...        ...        ...       ...        ...
# 515     516 2023-05-01        1.0     60000       61.0
# 516     517        NaT        0.0         0        NaN
# 517     518        NaT        0.0         0        NaN
# 518     519 2023-06-01        6.0    360000       30.0
# 519     520 2023-06-01        6.0    360000       30.0
#
# [520 rows x 5 columns]

# %%
RFM['Recency_y'].value_counts()
# Out:
# Recency_y
# 300.0    166
# 30.0     164
# 61.0      97
# 91.0      49
# 122.0     34
# 181.0      9
# 150.0      1
# Name: count, dtype: int64

# %%
RFM['Recency_y'].fillna(300, inplace=True)
a1, a2, a3, a4 = np.percentile(RFM['Recency_y'], [20,40,60,80])
a1, a2, a3, a4
# Out:
# (30.0, 61.0, 122.0, 300.0)

# %%
def percent(x):
    if x <= a1:
        return 1  # 충성, 신규
    elif x > a1 and x <= a2:
        return 2
    elif x > a2 and x <= a3:
        return 3
    elif x > a3 and x < a4:
        return 4
    elif x >= a4:
        return 5  # 무료 회원

# %%
RFM['Recency_score'] = RFM['Recency_y'].apply(percent)
RFM
# Out:
#      userid  Recency_x  Frequency  Monetary  Recency_y  Recency_score
# 0         1 2023-01-01        1.0     60000      181.0              4
# 1         2 2023-05-01        2.0    120000       61.0              2
# 2         3 2023-06-01        4.0    240000       30.0              1
# 3         4 2023-06-01        4.0    240000       30.0              1
# 4         5 2023-06-01        4.0    240000       30.0              1
# ..      ...        ...        ...       ...        ...            ...
# 515     516 2023-05-01        1.0     60000       61.0              2
# 516     517        NaT        0.0         0      300.0              5
# 517     518        NaT        0.0         0      300.0              5
# 518     519 2023-06-01        6.0    360000       30.0              1
# 519     520 2023-06-01        6.0    360000       30.0              1
#
# [520 rows x 6 columns]

# %%
RFM['Frequency'].value_counts()
# Out:
# Frequency
# 0.0    166
# 1.0    160
# 2.0     84
# 4.0     40
# 3.0     32
# 5.0     26
# 6.0     12
# Name: count, dtype: int64

# %%
b1, b2, b3, b4 = np.percentile(RFM['Frequency'], [20,40,80,95])
b1, b2, b3, b4
# Out:
# (0.0, 1.0, 3.0, 5.0)

# %%
def percent(x):
    if x == b1:
        return 5  # 무료
    elif x > b1 and x <= b2:
        return 4  # 이탈
    elif x > b2 and x <= b3:
        return 3
    elif x > b3 and x < b4:
        return 2
    elif x >= b4:
        return 1  # 충성회원

# %%
RFM['Frequency_score'] = RFM['Frequency'].apply(percent)
RFM
# Out:
#      userid  Recency_x  Frequency  Monetary  Recency_y  Recency_score  \
# 0         1 2023-01-01        1.0     60000      181.0              4
# 1         2 2023-05-01        2.0    120000       61.0              2
# 2         3 2023-06-01        4.0    240000       30.0              1
# 3         4 2023-06-01        4.0    240000       30.0              1
# 4         5 2023-06-01        4.0    240000       30.0              1
# ..      ...        ...        ...       ...        ...            ...
# 515     516 2023-05-01        1.0     60000       61.0              2
# 516     517        NaT        0.0         0      300.0              5
# 517     518        NaT        0.0         0      300.0              5
# 518     519 2023-06-01        6.0    360000       30.0              1
# 519     520 2023-06-01        6.0    360000       30.0              1
#
#      Frequency_score
# 0                  4
# 1                  3
# 2                  2
# 3                  2
# 4                  2
# ..               ...
# 515                4
# 516                5
# 517                5
# 518                1
# 519                1
#
# [520 rows x 7 columns]

# %%
RFM['Monetary'].value_counts()
# Out:
# Monetary
# 0         166
# 60000     160
# 120000     84
# 240000     40
# 180000     32
# 300000     26
# 360000     12
# Name: count, dtype: int64

# %%
c1, c2, c3, c4 = np.percentile(RFM['Monetary'], [20,40,80,95])
c1, c2, c3, c4
# Out:
# (0.0, 60000.0, 180000.0, 300000.0)

# %%
def percent(x):
    if x == c1:
        return 5  # 무료
    elif x > c1 and x <= c2:
        return 4  # 이탈
    elif x > c2 and x <= c3:
        return 3
    elif x > c3 and x < c4:
        return 2
    elif x >= c4:
        return 1  # 충성회원

# %%
RFM['Monetary_score'] = RFM['Monetary'].apply(percent)
RFM
# Out:
#      userid  Recency_x  Frequency  Monetary  Recency_y  Recency_score  \
# 0         1 2023-01-01        1.0     60000      181.0              4
# 1         2 2023-05-01        2.0    120000       61.0              2
# 2         3 2023-06-01        4.0    240000       30.0              1
# 3         4 2023-06-01        4.0    240000       30.0              1
# 4         5 2023-06-01        4.0    240000       30.0              1
# ..      ...        ...        ...       ...        ...            ...
# 515     516 2023-05-01        1.0     60000       61.0              2
# 516     517        NaT        0.0         0      300.0              5
# 517     518        NaT        0.0         0      300.0              5
# 518     519 2023-06-01        6.0    360000       30.0              1
# 519     520 2023-06-01        6.0    360000       30.0              1
#
#      Frequency_score  Monetary_score
# 0                  4               4
# 1                  3               3
# 2                  2               2
# 3                  2               2
# 4                  2               2
# ..               ...             ...
# 515                4               4
# 516                5               5
# 517                5               5
# 518                1               1
# 519                1               1
#
# [520 rows x 8 columns]

# %% [markdown]
# - RFM 스코어 합치기

# %%
RFM['RFM_score'] = RFM['Recency_score'].astype(str) + RFM['Frequency_score'].astype(str) + RFM['Monetary_score'].astype(str)
RFM
# Out:
#      userid  Recency_x  Frequency  Monetary  Recency_y  Recency_score  \
# 0         1 2023-01-01        1.0     60000      181.0              4
# 1         2 2023-05-01        2.0    120000       61.0              2
# 2         3 2023-06-01        4.0    240000       30.0              1
# 3         4 2023-06-01        4.0    240000       30.0              1
# 4         5 2023-06-01        4.0    240000       30.0              1
# ..      ...        ...        ...       ...        ...            ...
# 515     516 2023-05-01        1.0     60000       61.0              2
# 516     517        NaT        0.0         0      300.0              5
# 517     518        NaT        0.0         0      300.0              5
# 518     519 2023-06-01        6.0    360000       30.0              1
# 519     520 2023-06-01        6.0    360000       30.0              1
#
#      Frequency_score  Monetary_score RFM_score
# 0                  4               4       444
# 1                  3               3       233
# 2                  2               2       122
# 3                  2               2       122
# 4                  2               2       122
# ..               ...             ...       ...
# 515                4               4       244
# 516                5               5       555
# 517                5               5       555
# 518                1               1       111
# 519                1               1       111
#
# [520 rows x 9 columns]

# %%
RFM['RFM_score'].value_counts().sort_index()
# Out:
# RFM_score
# 111     31
# 122     19
# 133     53
# 144     61
# 211      7
# 222     15
# 233     36
# 244     39
# 322      6
# 333     26
# 344     51
# 433      1
# 444      9
# 555    166
# Name: count, dtype: int64

# %%
RFM[RFM['RFM_score']=='333'].head()
# Out:
#     userid  Recency_x  Frequency  Monetary  Recency_y  Recency_score  \
# 14      15 2023-04-01        2.0    120000       91.0              3
# 15      16 2023-04-01        2.0    120000       91.0              3
# 17      18 2023-03-01        2.0    120000      122.0              3
# 19      20 2023-03-01        2.0    120000      122.0              3
# 21      22 2023-03-01        2.0    120000      122.0              3
#
#     Frequency_score  Monetary_score RFM_score
# 14                3               3       333
# 15                3               3       333
# 17                3               3       333
# 19                3               3       333
# 21                3               3       333

# %%
spotify[spotify['userid']==18]
# Out:
#      userid  spotify_subscription_plan_x  revenue timestamp_x timestamp_y  \
# 102      18  Premium (paid subscription)    60000  2023-01-01  2023-07-01
# 103      18          Free (ad-supported)        0  2023-02-01  2023-07-01
# 104      18  Premium (paid subscription)    60000  2023-03-01  2023-07-01
# 105      18          Free (ad-supported)        0  2023-04-01  2023-07-01
# 106      18          Free (ad-supported)        0  2023-05-01  2023-07-01
# 107      18          Free (ad-supported)        0  2023-06-01  2023-07-01
#
#        Age  Gender spotify_usage_period spotify_listening_device  \
# 102  20-35  Female   Less than 6 months               Smartphone
# 103  20-35  Female   Less than 6 months               Smartphone
# 104  20-35  Female   Less than 6 months               Smartphone
# 105  20-35  Female   Less than 6 months               Smartphone
# 106  20-35  Female   Less than 6 months               Smartphone
# 107  20-35  Female   Less than 6 months               Smartphone
#
#     spotify_subscription_plan_y  ...        music_Influencial_mood  \
# 102         Free (ad-supported)  ...  Social gatherings or parties
# 103         Free (ad-supported)  ...  Social gatherings or parties
# 104         Free (ad-supported)  ...  Social gatherings or parties
# 105         Free (ad-supported)  ...  Social gatherings or parties
# 106         Free (ad-supported)  ...  Social gatherings or parties
# 107         Free (ad-supported)  ...  Social gatherings or parties
#
#     music_lis_frequency music_expl_method music_recc_rating pod_lis_frequency  \
# 102   Social gatherings   recommendations                 4             Never
# 103   Social gatherings   recommendations                 4             Never
# 104   Social gatherings   recommendations                 4             Never
# 105   Social gatherings   recommendations                 4             Never
# 106   Social gatherings   recommendations                 4             Never
# 107   Social gatherings   recommendations                 4             Never
#
#     fav_pod_genre preffered_pod_format pod_host_preference  \
# 102           NaN                  NaN                 NaN
# 103           NaN                  NaN                 NaN
# 104           NaN                  NaN                 NaN
# 105           NaN                  NaN                 NaN
# 106           NaN                  NaN                 NaN
# 107           NaN                  NaN                 NaN
#
#      preffered_pod_duration pod_variety_satisfaction
# 102                     NaN                       Ok
# 103                     NaN                       Ok
# 104                     NaN                       Ok
# 105                     NaN                       Ok
# 106                     NaN                       Ok
# 107                     NaN                       Ok
#
# [6 rows x 25 columns]

# %% [markdown]
# RFM Segment
#
# > 충성고객 :
# - 111(7월 프리미엄 o), 211(7월 프리미엄 o)
# > 이탈우려고객 : 많은 금액 소비하고, 자주 구매했었으나, 최근 구매하지 않은 고객
# - 122(7월 프리미엄 x)
# > 잠재충성고객 : 3번이상 구매한 고객
# - 222(7월 프리미엄 o), 322(7월 프리미엄 o)
# > 관심필요고객 : 최근성, 구매빈도, 구매금액 평균 이상인 고객
# - 433 (유료(1,2월)-> 무료(3,4,5,6월)) 7월 프리미엄 o
# > 신규고객 : 최근에 구매했으나 자주 방문하지 않은 고객 (무료->유료(6월))
# - 144(7월 프리미엄 x), 133(7월 프리미엄 x), 233(7월 프리미엄 x), 244(7월 프리미엄 x)
# > 휴면고객 : 적은 금액 소비하고, 오래전에 방문한 고객(유료(1월)->무료전환), 한번 결제후 무료 전환
# - 444, 344, 333
# > 무료회원 : 구매이력 X
# - 555
