# %%
import pandas as pd
# Out:
# /var/folders/qv/tqmmyp0s5dj996k_tcvqmtqm0000gn/T/ipykernel_3594/217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('/Users/hj/Documents/무제/실전프로젝트/스파르타(튜터) - 스포티파이 데이터.csv')
df
# Out:
#      userid   timestamp    Age  Gender spotify_usage_period  \
# 0        24  2023-07-01  20-35  Female    More than 2 years
# 1        25  2023-07-01  20-35    Male    More than 2 years
# 2        27  2023-07-01  12-20    Male   6 months to 1 year
# 3        50  2023-07-01  20-35    Male    1 year to 2 years
# 4        60  2023-07-01  20-35    Male    More than 2 years
# ..      ...         ...    ...     ...                  ...
# 515     514  2023-07-01  20-35  Female    More than 2 years
# 516     515  2023-07-01  20-35  Female    More than 2 years
# 517     516  2023-07-01  20-35  Female    More than 2 years
# 518     517  2023-07-01  20-35  Female    More than 2 years
# 519     518  2023-07-01  20-35  Female    More than 2 years
#
#                               spotify_listening_device  \
# 0    Smartphone, Computer or laptop, Smart speakers...
# 1                       Smartphone, Computer or laptop
# 2       Smartphone, Smart speakers or voice assistants
# ...

# %%
dd = pd.read_csv('/Users/hj/Documents/무제/실전프로젝트/rfm_score.csv')
dd
# Out:
#      userid     Recency  Frequency  Monetary  Monetary_score  Recency_score  \
# 0         1  2023-01-01          1     60000               1              1
# 1         2  2023-05-01          2    120000               2              4
# 2         3  2023-06-01          4    240000               4              5
# 3         4  2023-06-01          4    240000               4              5
# 4         5  2023-06-01          4    240000               4              5
# ..      ...         ...        ...       ...             ...            ...
# 515     516  2023-05-01          1     60000               1              4
# 516     517         NaN          0         0               0              0
# 517     518         NaN          0         0               0              0
# 518     519  2023-07-01          7    420000               7              6
# 519     520  2023-07-01          7    420000               7              6
#
#      RFM_score   Grade
# 0          111    휴면고객
# ...

# %%
spotify = pd.merge(df, dd, on = 'userid', how='outer')
spotify
# Out:
#      userid   timestamp    Age  Gender spotify_usage_period  \
# 0         1  2023-07-01  20-35  Female    More than 2 years
# 1         2  2023-07-01  12-20    Male    More than 2 years
# 2         3  2023-07-01  35-60  Others   6 months to 1 year
# 3         4  2023-07-01  20-35  Female    1 year to 2 years
# 4         5  2023-07-01  20-35  Female    1 year to 2 years
# ..      ...         ...    ...     ...                  ...
# 515     516  2023-07-01  20-35  Female    More than 2 years
# 516     517  2023-07-01  20-35  Female    More than 2 years
# 517     518  2023-07-01  20-35  Female    More than 2 years
# 518     519  2023-07-01  20-35  Female   6 months to 1 year
# 519     520  2023-07-01  20-35  Female    More than 2 years
#
#                              spotify_listening_device  \
# 0                  Smart speakers or voice assistants
# 1                                  Computer or laptop
# 2                  Smart speakers or voice assistants
# ...

# %%
# spotify.to_csv('./spotify+rfm.csv', index=False)

# %%
gg = pd.read_csv('/Users/hj/Documents/무제/실전프로젝트/스파르타(튜터) - 매출지표.csv')
gg
# Out:
#       userid    spotify_subscription_plan  revenue   timestamp
# 0          1  Premium (paid subscription)    60000  2023-01-01
# 1          2  Premium (paid subscription)    60000  2023-01-01
# 2          3  Premium (paid subscription)    60000  2023-01-01
# 3          4  Premium (paid subscription)    60000  2023-01-01
# 4          5  Premium (paid subscription)    60000  2023-01-01
# ...      ...                          ...      ...         ...
# 3115     516          Free (ad-supported)        0  2023-06-01
# 3116     517          Free (ad-supported)        0  2023-06-01
# 3117     518          Free (ad-supported)        0  2023-06-01
# 3118     519  Premium (paid subscription)    60000  2023-06-01
# 3119     520  Premium (paid subscription)    60000  2023-06-01
#
# [3120 rows x 4 columns]

# %%
spotify_1 = pd.merge(spotify, gg, on = 'userid', how='outer')
spotify_1
# Out:
#       userid timestamp_x    Age  Gender spotify_usage_period  \
# 0          1  2023-07-01  20-35  Female    More than 2 years
# 1          1  2023-07-01  20-35  Female    More than 2 years
# 2          1  2023-07-01  20-35  Female    More than 2 years
# 3          1  2023-07-01  20-35  Female    More than 2 years
# 4          1  2023-07-01  20-35  Female    More than 2 years
# ...      ...         ...    ...     ...                  ...
# 3115     520  2023-07-01  20-35  Female    More than 2 years
# 3116     520  2023-07-01  20-35  Female    More than 2 years
# 3117     520  2023-07-01  20-35  Female    More than 2 years
# 3118     520  2023-07-01  20-35  Female    More than 2 years
# 3119     520  2023-07-01  20-35  Female    More than 2 years
#
#                 spotify_listening_device  spotify_subscription_plan_x  \
# 0     Smart speakers or voice assistants          Free (ad-supported)
# 1     Smart speakers or voice assistants          Free (ad-supported)
# ...

# %%
unsatisfact = spotify_1[spotify_1['pod_variety_satisfaction'] in ['Dissatisfied', 'Very Dissatisfied']]
unsatisfact
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qv/tqmmyp0s5dj996k_tcvqmtqm0000gn/T/ipykernel_3594/576320940.py in ?()
# ----> 1 unsatisfact = spotify_1[spotify_1['pod_variety_satisfaction'] in ['Dissatisfied', 'Very Dissatisfied']]
#       2 unsatisfact
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1574     @final
#    1575     def __nonzero__(self) -> NoReturn:
# -> 1576         raise ValueError(
#    1577             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1578             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1579         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
